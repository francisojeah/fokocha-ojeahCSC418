# %% [markdown]
# # Sheared Image in Y-Axis

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

img = cv.imread('../images/exercise-images/sst.jpg', 0)
rows, cols = img.shape

# Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(img)

M = np.float32([[1, 0, 0], [0.5, 1, 0], [0, 0, 1]])
sheared_img = cv.warpPerspective(img, M, (int(cols*1.5), int(rows*1.5)))

# Plot the sheared image
plt.subplot(1, 2, 2)
plt.title("Sheared Image Y-Axis")
plt.imshow(sheared_img)

# Save the sheared image
cv.imwrite("../images/exercise-images/sheared_Y_out.jpg", sheared_img)

plt.show()
