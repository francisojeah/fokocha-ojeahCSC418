# %% [markdown]
# # Arthmetic Operations on Images | OpenCV

# %% [markdown]
# ## Addition of Image

# %%
# A program to illustrate arithmetic operation of addition

# organizing imports
import cv2
import matplotlib.pyplot as plt

# path to input images 
image1 = cv2.imread("img/sst.jpg")
image2 = cv2.imread("img/sst-foyer.jpg")

#resize images
image1 = cv2.resize(image1, (500,400))
image2 = cv2.resize(image2, (500,400))

# cv2.addWeighted with applied parameters
addImage = cv2.addWeighted(image1, 0.5, image2, 0.6, 0)

# Convert BGR to RGB for displaying with Matplotlib
addImage_rgb = cv2.cvtColor(addImage, cv2.COLOR_BGR2RGB)

# Plot the weighted image
plt.imshow(addImage_rgb)
plt.title("Weighted Image")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Subtraction of Image

# %%
# A program to illustrate arithmetic operation of addition

# organizing imports
import cv2
import matplotlib.pyplot as plt

# path to input images 
image1 = cv2.imread("img/sst.jpg")
image2 = cv2.imread("img/sst-foyer.jpg")

#resize images
image1 = cv2.resize(image1, (500,400))
image2 = cv2.resize(image2, (500,400))

sub = cv2.subtract(image1, image2)

# Convert BGR to RGB for displaying with Matplotlib
sub_rgb = cv2.cvtColor(sub, cv2.COLOR_BGR2RGB)

# Plot the weighted image
plt.imshow(sub_rgb)
plt.title("Subtracted Image")
plt.axis("off")
plt.show()
